# %% [markdown]
# # Notebook
#
# ToDo: add validation

# %%
import os
from dhydro2isg.dhydro2isg import dhydro_to_stf
from dhydro2isg.stf import STF

folder = r"c:\Users\905872\Haskoning\P-BK8839-WSVV-detachering-hydroloog - Team\WIP\01_modelbouw\Modellen\A Basismodel\02_wip\A Basismodel_0.23b_stationair_zonder_knip\Project1.dsproj_data\DFM"
output_folder = r"c:\Users\905872\Downloads\temp"
wip_folder = os.path.join(output_folder, 'WIP')
os.makedirs(wip_folder, exist_ok=True)

start_time = "2000-01-15"
end_time = "2000-01-17"

dhydro_network_nc = os.path.join(folder, 'input', 'Vallei_net.nc')
dhydro_map_nc = os.path.join(folder,'output', 'DFM_map.nc')
crossloc_ini = os.path.join(folder, 'input', 'cross_section_locations.ini')
crossdef_ini = os.path.join(folder, 'input', 'cross_section_definitions.ini')


stf = dhydro_to_stf(dhydro_network_nc=dhydro_network_nc,
                    dhydro_map_nc=dhydro_map_nc,
                    crossloc_ini=crossloc_ini,
                    crossdef_ini=crossdef_ini,
                    output_name="test_output",
                    start_time=start_time,
                    end_time=end_time,
                    resistance=1,
                    infiltration=0.3,
                    mrc=25,
                    epsg=28992,
                    output_folder=wip_folder)

stf.clean_stf(minlength=10)
stf.export_to_shape(export_folder=str(output_folder), filename='test_output')
stf.export_to_isg(export_folder=str(output_folder), filename='test_output_isg')

# new = STF()
# new.import_from_shape(import_folder=output_folder, prefix_filename='Merkske_Q40_test')
# new.export_to_isg("Merkske_Q40_test_re-read", export_folder=str(output_folder))
# Out:
# import succeeded
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 32
#      16 crossdef_ini = os.path.join(folder, 'input', 'cross_section_definitions.ini')
#      19 stf = dhydro_to_stf(dhydro_network_nc=dhydro_network_nc,
#      20                     dhydro_map_nc=dhydro_map_nc,
#      21                     crossloc_ini=crossloc_ini,
#    (...)     29                     epsg=28992,
#      30                     output_folder=wip_folder)
# ---> 32 stf.clean_stf(minlength=10)
#      33 stf.export_to_shape(export_folder=str(output_folder), filename='test_output')
#      34 stf.export_to_isg(export_folder=str(output_folder), filename='test_output_isg')
#
# File c:\Users\905872\AppData\Local\anaconda3\envs\dhydro2isg\Lib\site-packages\dhydro2isg\stf.py:67, in STF.clean_stf(self, minlength)
#      64 if minlength:
# ...
